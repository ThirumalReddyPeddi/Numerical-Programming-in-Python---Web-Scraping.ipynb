# %% [markdown]
# <a href="https://colab.research.google.com/github/ThirumalReddyPeddi/Numerical-Programming-in-Python---Web-Scraping.ipynb/blob/main/05_TVShow_Data_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Fetching Tv Show Title details**

# %%
# Create an empty list to store the titles of all TV shows
tv_show_titles = []

# Loop through each TV show URL extracted from the JustWatch website
for url in tv_show_urls:

    try:
        # Send an HTTP GET request to the current TV show page
        response = requests.get(
            url,
            headers=headers
        )

        # Parse the HTML content of the TV show page
        soup = BeautifulSoup(
            response.text,
            "html.parser"
        )

        # Find the <h1> tag that contains the TV show title
        # The title is located inside the element with the class
        # 'title-detail-hero__details__title'
        title_tag = soup.select_one(
            "h1.title-detail-hero__details__title"
        )

        # Check whether the title element exists
        if title_tag:

            # Extract the TV show title, remove any extra spaces,
            # and store it in the list
            title = title_tag.contents[0].strip()

        else:
            # If the title is not available, store NaN
            title = np.nan

        # Add the extracted title to the tv_show_titles list
        tv_show_titles.append(title)

    except Exception as e:
        # If any error occurs while fetching or parsing the page,
        # store NaN to maintain alignment with the URL list
        tv_show_titles.append(np.nan)

# Print the total number of TV show titles extracted
print("Total TV Show Titles Scraped:", len(tv_show_titles))

# Print the list of extracted TV show titles
print("TV Show Titles:")
print(tv_show_titles)
# Out:
# Total TV Show Titles Scraped: 105
# TV Show Titles:
# ['The Vampire Diaries', 'Dutton Ranch', 'Mad Men', 'Breaking Bad', 'NCR Days', 'Cape Fear', 'Overflow', 'The WONDERfools', 'Resort', 'Janaawar: The Beast within', 'Naruto Shippūden', nan, 'Inspector Avinash', 'Perfect Crown', 'MTV Roadies', 'Maximum Pleasure Guaranteed', 'Glory', 'Black Clover', nan, 'Gyaarah Gyaarah', 'S Line', 'Peaky Blinders', 'Weak Hero', 'The Boroughs', 'Laughter Chefs Unlimited Entertainment', 'Undekhi', 'Bloodhounds', 'Teach You a Lesson', 'MTV Splitsvilla', 'Dark', 'Charitraheen', 'Panchayat', 'Berlín', 'Matka King', "Georgie & Mandy's First Marriage", "Widow's Bay", 'Gullak', 'Chiraiya', 'Maamla Legal Hai', 'Lost', 'Off Campus', 'FROM', 'Gandii Baat', 'Night Has Come', 'Stranger Things', 'Solo Leveling', "A Good Girl's Guide to Murder", 'The Jewel of Section E', 'Classroom of the Elite', 'Sex', 'Gutar Gu', 'Naagin', 'Farzi', '24', 'Absolute Value of Romance', 'Monarch: Legacy of Monsters', 'Kimetsu no Yaiba', 'Game of Thrones', 'Prison Break', 'All of Us Are Dead', 'Spider-Noir', 'The Rookie', 'XXX: Uncensored', 'The Summer I Turned Pretty', 'Thukra Ke Mera Pyaar', 'Mastram', 'Kaisi Yeh Yaariyan', 'Every Year After', 'She', 'Erotic Stories', 'The Boys', nan, 'Spartacus', 'Sapne Vs Everyone', 'Daredevil: Born Again', 'Spartacus: House of Ashur', 'Person of Interest', 'Scam 1992: The Harshad Mehta Story', 'Rick and Morty', 'A Knight of the Seven Kingdoms', nan, 'Made in India: A Titan Story', 'Euphoria', 'Study Group', 'Mahabharatham', 'Berlin and the Lady with an Ermine', 'Ben 10', 'Mirzapur', nan, 'Dark Desire', 'House of the Dragon', 'Shingeki no Kyojin', 'Money Heist', 'Do You Like Big Girls?', 'The Family Man', 'If Wishes Could Kill', "Margo's Got Money Troubles", 'Obsession', 'Devil May Cry', 'Jujutsu Kaisen', 'The Pyramid Scheme', 'Naruto', 'Dr. STONE', 'Wistoria: Wand and Sword', 'Bigg Boss']

# %% [markdown]
# ## **Fetching Release Year**

# %%
# Create an empty list to store the release years of all TV shows
release_years = []

for url in tv_show_urls:

    response = requests.get(
        url,
        headers=headers
    )


    soup = BeautifulSoup(
        response.text,
        "html.parser"
    )

    # Find the <span> element that contains the release year
    # Example: <span class="release-year">(2022)</span>

    year_tag = soup.select_one(
        "span.release-year"
    )

    # Check whether the release year element exists
    # If found, extract the text, remove extra spaces,
    # and remove the surrounding parentheses.
    # Otherwise, store NaN.

    release_years.append(
        year_tag.get_text(strip=True).strip("()")
        if year_tag else np.nan
    )

# Print the total number of release years extracted

print( len(release_years))

# Print the list of extracted release years


print(release_years)
# Out:
# 105
# ['2009', '2026', '2007', '2008', '2022', '2026', '2020', '2026', '2026', '2025', '2007', '2021', '2023', '2026', '2003', '2026', '2026', '2017', '2025', '2024', '2025', '2013', '2022', '2026', '2024', '2020', '2023', '2026', '2008', '2017', '2018', '2020', '2023', '2026', '2024', '2026', '2019', '2026', '2024', '2004', '2026', '2022', '2018', '2023', '2016', '2024', '2024', '2025', '2017', '2020', '2023', '2015', '2023', '2013', '2026', '2023', '2019', '2011', '2005', '2022', '2026', '2018', '2018', '2022', '2024', '2020', '2014', '2026', '2020', '2023', '2019', '2011', '2010', '2023', '2025', '2025', '2011', '2020', '2013', '2026', '2015', '2026', '2019', '2025', '2013', '2026', '2005', '2018', '2008', '2020', '2022', '2013', '2017', '2026', '2019', '2026', '2026', '2023', '2025', '2020', '2026', '2002', '2019', '2024', '2006']

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Create an empty list to store the genres of all TV shows
genres = []

for url in tv_show_urls:


    response = requests.get(
        url,
        headers=headers
    )


    soup = BeautifulSoup(
        response.text,
        "html.parser"
    )

    # Initialize the genre variable with NaN
    # This value will be used if no genre information is found

    genre = np.nan

    # Find all <h3> elements that represent information headings
    # such as Genres, Age rating, Runtime, etc.

    for heading in soup.find_all(
        "h3",
        class_="poster-detail-infos__subheading"
    ):

        # Check whether the current heading is "Genres"

        if heading.get_text(strip=True) == "Genres":

            # Find the next <div> element containing the genre details

            genre_div = heading.find_next(
                "div",
                class_="poster-detail-infos__value"
            )

            # Extract the genre text, remove extra spaces,
            # and clean the formatting
            # Example:
            # "Drama, Crime , Organized Crime"
            # becomes
            # "Drama, Crime, Organized Crime"

            genre = genre_div.get_text(
                separator=" ",
                strip=True
            ).replace(" , ", ", ")

            # Stop searching once the genre section is found

            break

    # Add the extracted genre information to the list

    genres.append(genre)

# Print the total number of genre entries extracted
print( len(genres))

# Print the list of extracted TV show genres

print(genres)
# Out:
# 105
# ['Drama, Science-Fiction, Horror, Romance, Mystery & Thriller, Fantasy, Young Adult Drama, Modern Fantasy', 'Western, Drama, Epic Western', 'Drama, Emotional Drama, Based On A True Story, Period Drama', 'Drama, Mystery & Thriller, Crime, Dark Crime', 'Drama, Emotional Drama', 'Drama, Crime, Mystery Thriller', 'Animation, Classic Japanese Anime', 'Comedy, Science-Fiction, Drama, Action & Adventure', 'Comedy, Drama', 'Action & Adventure, Crime, Action Thriller', 'Action & Adventure, Science-Fiction, Animation, Comedy, Drama, Fantasy, Classic Japanese Anime', 'Drama, Comedy, Romance', 'Action & Adventure, Mystery & Thriller, Crime, Action Thriller', 'Comedy, Drama, Romance', 'Reality TV, Action & Adventure', 'Comedy, Mystery Thriller', 'Drama, Mystery & Thriller, Action & Adventure, Sport', 'Comedy, Science-Fiction, Drama, Kids & Family, Fantasy, Mystery & Thriller, Animation, Action & Adventure, Classic Japanese Anime', 'Reality TV', 'Drama, Fantasy, Science-Fiction, Modern Fantasy', 'Science-Fiction, Drama, Fantasy, Mystery Thriller', 'Drama, Crime, Organized Crime', 'Drama, Mystery & Thriller, Action Adventure', 'Science-Fiction, Mystery & Thriller, Drama, Fantasy', 'Comedy, Reality TV, Kids & Family, Bollywood', 'Drama, Crime, Bollywood', 'Action & Adventure, Crime, Drama, Sport, Mystery & Thriller, Action Thriller', 'Action & Adventure, Drama, Comedy', 'Reality TV, Drama, Romance', 'Science-Fiction, Drama, Mystery & Thriller, Crime, Cerebral', 'Drama, Mystery Thriller', 'Comedy, Drama, Bollywood', 'Action & Adventure, Crime, Drama, Mystery & Thriller, Heist', 'Drama, Crime, Organized Crime', 'Comedy, RomCom', 'Drama, Horror, Comedy, Mystery Thriller', 'Kids & Family, Comedy, Drama, Bollywood, Dramedy', 'Drama, Emotional Drama', 'Drama, Comedy, Dramedy', 'Drama, Fantasy, Science-Fiction, Action Adventure, Mystery Thriller', 'Romance, Sport, Drama, Romantic Drama', 'Drama, Science-Fiction, Horror, Mystery Thriller', 'Crime, Drama, Mystery & Thriller, Bollywood', 'Drama, Horror, Mystery Thriller', 'Mystery & Thriller, Science-Fiction, Drama, Fantasy, Horror, Young Adult Drama, Sci-Fi Drama, Monster', 'Action & Adventure, Fantasy, Animation, Science-Fiction, Classic Japanese Anime', 'Drama, Crime, Mystery Thriller', 'Drama, Comedy, Romance, Dramedy', 'Mystery & Thriller, Animation, Drama, Classic Japanese Anime', 'Drama, Romantic Drama', 'Romance, Drama, Comedy, Bollywood, Romantic Drama', 'Action & Adventure, Mystery & Thriller, Science-Fiction, Drama, Fantasy, Bollywood', 'Drama, Crime, Mystery & Thriller, Bollywood', 'Mystery & Thriller, Action & Adventure, Crime, Drama, Bollywood', 'Drama, Comedy', 'Science-Fiction, Drama, Action & Adventure, Invasion', 'Animation, Action & Adventure, Fantasy, Mystery & Thriller, Science-Fiction, Classic Japanese Anime', 'Drama, Action & Adventure, Science-Fiction, Fantasy, Epic Fantasy, Epic', 'Action & Adventure, Crime, Drama, Mystery & Thriller, Made in Europe, Dark Crime, Action Thriller', 'Science-Fiction, Action & Adventure, Drama, Fantasy, Horror, Mystery & Thriller, Zombie', 'Crime, Drama, Fantasy, Science-Fiction, Mystery & Thriller, Action & Adventure, Superhero', 'Action & Adventure, Crime, Drama, Comedy, Detective Crime', 'Comedy, Drama, Romance, Bollywood', 'Romance, Drama, Romantic Drama', 'Drama, Romance, Bollywood, Romantic Drama', 'Drama, Comedy, Fantasy, Bollywood', 'Drama, Bollywood', 'Romance, Drama', 'Drama, Crime, Bollywood', 'Drama, Emotional Drama, Romantic Thriller', 'Action & Adventure, Science-Fiction, Drama, Comedy, Crime, No Superhero', 'Drama, Action & Adventure, Crime, Mystery & Thriller', 'Drama, Romance, History, Action Adventure, Epic', 'Drama, Psychological Drama', 'Crime, Drama, Fantasy, Science-Fiction, Mystery & Thriller, Superhero, Action Adventure', 'Drama, Action & Adventure, Period Drama', 'Science-Fiction, Drama, Action & Adventure, Crime, Mystery & Thriller, Detective Crime, Action Thriller', 'Crime, Drama, Mystery & Thriller, Bollywood', 'Animatio ...

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Create an empty list to store the IMDb ratings of all TV shows
imdb_ratings = []

for url in tv_show_urls:

    try:

        response = requests.get(
            url,
            headers=headers
        )

        soup = BeautifulSoup(
            response.text,
            "html.parser"
        )

        # Find the HTML element that contains the IMDb rating
        # The IMDb score is stored inside the <span> tag
        # with the class "imdb-score"

        imdb_tag = soup.select_one(
            "span.imdb-score"
        )

        # Check whether the IMDb rating element exists
        # If found, extract only the rating value.
        # Example:
        # "8.4 (1.3k)" -> "8.4"
        # Otherwise, store NaN.

        imdb_rating = (
            imdb_tag.get_text(strip=True).split()[0]
            if imdb_tag else np.nan
        )

        # Add the extracted IMDb rating to the list
        imdb_ratings.append(imdb_rating)

    except Exception:
        # If any error occurs while fetching or parsing the page,
        # store NaN to maintain alignment with the URL list.

        imdb_ratings.append(np.nan)

# Print the total number of IMDb ratings extracted
print(len(imdb_ratings))

# Print the list of extracted IMDb ratings

print(imdb_ratings)
# Out:
# 105
# ['7.7', '8.4', '8.7', '9.5', '8.9', nan, '6.7', nan, '8.8', '6.8', '8.7', '7.8', '7.6', nan, '4.5', nan, '6.7', '8.2', '5.6', '8.1', '6.3', '8.7', '8.4', '7.4', '8.4', nan, '8.1', nan, '3.8', '8.7', '5.1', '9.0', '7.0', '7.2', '7.1', '8.3', '9.1', nan, '8.0', '8.3', '8.0', '7.8', '3.4', '7.3', '8.6', '8.5', '6.8', '7.4', '7.7', '5.8', '8.3', '3.7', '8.3', '8.1', '6.7', '7.0', '8.6', '9.2', '8.3', '7.6', '8.1', '8.0', '4.8', '7.2', '6.5', '6.8', '8.0', nan, '6.4', '5.3', '8.6', '7.4', '8.4', '9.2', '8.0', '6.5', '8.5', '9.2', '9.0', '8.7', '7.2', '8.7', '8.1', '8.2', '8.7', '7.1', '7.6', '8.4', '7.4', '6.5', '8.3', '9.1', '8.2', nan, '8.7', '7.1', '6.6', '5.2', '7.4', '8.5', nan, '8.4', '8.1', '7.5', '3.6']

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Create an empty list to store the age ratings of all TV shows

age_ratings = []


for url in tv_show_urls:


    response = requests.get(
        url,
        headers=headers
    )


    soup = BeautifulSoup(
        response.text,
        "html.parser"
    )

    # Find the <h3> tag whose text is "Age rating"
    # This heading identifies the section containing the age rating information
    age_heading = soup.find(
        "h3",
        string="Age rating"
    )

    # Check whether the Age Rating section exists
    if age_heading:

        # Find the next <div> element containing the age rating value
        # and extract its text

        age_rating = age_heading.find_next(
            "div",
            class_="poster-detail-infos__value"
        ).get_text(strip=True)

    else:
        # If the age rating is not available, store NaN
        age_rating = np.nan

    # Add the extracted age rating to the list
    age_ratings.append(age_rating)

# Print the total number of age ratings extracted
print(len(age_ratings))

# Print the list of extracted age ratings

print(age_ratings)
# Out:
# 105
# ['U', nan, 'UA16+', 'A', 'UA16+', 'A', nan, 'UA16+', 'UA16+', nan, 'U', nan, 'A', 'UA16+', nan, 'A', 'A', nan, nan, 'A', 'A', 'A', nan, 'UA16+', nan, 'A', nan, 'A', 'U', 'A', 'A', 'UA16+', 'A', nan, nan, 'A', nan, 'A', 'UA13+', 'U', nan, nan, 'A', nan, 'UA16+', nan, nan, 'UA13+', 'UA16+', nan, 'UA16+', nan, 'UA16+', 'UA', 'UA16+', 'UA16+', 'A', 'A', 'U', 'A', 'UA16+', 'UA16+', nan, 'UA16+', 'UA16+', nan, nan, nan, 'UA16+', nan, 'A', nan, 'A', 'UA16+', nan, nan, 'U', 'U', 'UA16+', nan, nan, 'UA13+', 'A', nan, 'U', 'A', 'U', 'A', nan, 'A', 'A', nan, 'A', nan, nan, 'A', 'A', 'A', 'A', 'UA16+', 'UA13+', nan, nan, 'A', 'UA16+']

# %% [markdown]
# ## **Fetching Production Country details**

# %%
# Create an empty list to store the production country of all TV shows
production_countries = []


for url in tv_show_urls:

    response = requests.get(
        url,
        headers=headers
    )


    soup = BeautifulSoup(
        response.text,
        "html.parser"
    )

    # Find the <h3> tag whose text is "Production country"
    # This heading identifies the section containing
    # the production country information.

    country_heading = soup.find(
        "h3",
        string="Production country"
    )

    # Check whether the Production Country section exists
    # If found, locate the next <div> containing the country name
    # and extract the text. Otherwise, store NaN.

    production_countries.append(
        country_heading.find_next(
            "div",
            class_="poster-detail-infos__value"
        ).get_text(strip=True)
        if country_heading else np.nan
    )

# Print the total number of production country entries extracted
print(len(production_countries))

# Print the list of extracted production countries

print(production_countries)
# Out:
# 105
# ['United States', 'United States', 'United States', 'United States', 'India', 'United States', 'Japan', 'South Korea', 'India', 'India', 'Japan', 'South Korea', 'India', 'South Korea', 'India', 'United States', 'India', 'Japan', 'United States', 'India', 'South Korea', 'United Kingdom', 'South Korea', 'United States', 'India', 'India', 'South Korea', 'South Korea', 'India', 'Germany', 'India', 'India', 'Spain', 'India', 'United States', 'United States', 'India', 'India', 'India', 'United States', 'United States', 'United States', 'India', 'South Korea', 'United States', 'South Korea, Japan', 'United Kingdom, Germany', 'Philippines', 'Japan', 'Denmark', 'India', 'India', 'India', 'India', 'South Korea', 'United States', 'Japan', 'United States', 'United States', 'South Korea', 'United States', 'United States', 'India', 'United States', 'India', 'India', 'India', 'Canada, United States', 'India', 'Australia', 'United States', 'United States', 'United States', 'India', 'United States', 'United States', 'United States', 'India', 'United States', 'United States', 'United States', 'India', 'United States', 'South Korea', 'India', 'Spain', 'United States', 'India', 'United States', 'Mexico', 'United States', 'Japan', 'Spain', 'Japan', 'India', 'South Korea', 'United States', 'United Kingdom, France', 'United States', 'Japan, United States', 'India', 'Japan', 'Japan', 'Japan', 'India']

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
# Create an empty list to store the streaming services
# available for each TV show
streaming_services = []

for url in tv_show_urls:


    response = requests.get(
        url,
        headers=headers
    )


    soup = BeautifulSoup(
        response.text,
        "html.parser"
    )

    # Find all provider icons (<img> tags) that represent
    # the streaming platforms where the TV show is available

    providers = soup.find_all(
        "img",
        class_="provider-icon"
    )

    # Check whether any streaming providers are available
    if providers:

        # Extract the streaming service name from the
        # 'title' attribute of each provider icon

        service_names = [
            provider.get("title")
            for provider in providers
            if provider.get("title")
        ]

        # Remove duplicate service names while preserving
        # their original order and combine them into a
        # comma-separated string

        streaming_service = ", ".join(
            dict.fromkeys(service_names)
        )

    else:
        # If no streaming provider is found, store NaN
        streaming_service = np.nan

    # Add the extracted streaming service information
    # to the streaming_services list

    streaming_services.append(streaming_service)


# Define the set of OTT platforms that will be considered
# as valid primary streaming services

valid_services = {
    "Netflix",
    "Amazon Prime Video",
    "Amazon Prime Video with Ads",
    "JioHotstar",
    "Zee5",
    "Sun Nxt",
    "Sony LIV",
    "Aha",
    "Apple TV Store",
    "Amazon Video",
    "Hoichoi",
    "Eros Now",
    "MX Player",
    "Plex Player",
    "JustWatch",
    "Crunchyroll"
}

# Create an empty list to store the primary OTT platform
# for each TV show
primary_ott = []

# Loop through the extracted streaming service strings
for services in streaming_services:

    # Split the comma-separated services into a list
    # and remove any extra spaces
    service_list = [
        s.strip()
        for s in services.split(",")
    ]

    # Select the first service that belongs to the
    # predefined valid OTT platform list
    # If no valid service is found, return None
    ott = next(
        (
            s
            for s in service_list
            if s in valid_services
        ),
        None
    )

    # Add the selected primary OTT platform
    # to the primary_ott list
    primary_ott.append(ott)

# Print the total number of primary OTT platform entries
print(len(primary_ott))

# Print the primary OTT platform for each TV show

for prim_ott in primary_ott:
    print(prim_ott)
# Out:
# 105
# Amazon Prime Video
# JioHotstar
# Amazon Prime Video
# Netflix
# Crunchyroll
# Crunchyroll
# Amazon Prime Video
# Netflix
# JioHotstar
# Zee5
# Crunchyroll
# Amazon Prime Video
# JioHotstar
# JioHotstar
# Crunchyroll
# Crunchyroll
# Netflix
# Crunchyroll
# Crunchyroll
# Zee5
# Amazon Prime Video
# Netflix
# Netflix
# Netflix
# JioHotstar
# Crunchyroll
# Netflix
# Netflix
# JioHotstar
# Netflix
# Hoichoi
# Amazon Prime Video
# Netflix
# Amazon Prime Video
# JioHotstar
# Crunchyroll
# Crunchyroll
# JioHotstar
# Netflix
# JustWatch
# Amazon Prime Video
# Amazon Prime Video
# Crunchyroll
# JustWatch
# Netflix
# Crunchyroll
# Netflix
# JustWatch
# Crunchyroll
# JustWatch
# MX Player
# JioHotstar
# Amazon Prime Video
# JioHotstar
# Amazon Prime Video
# Crunchyroll
# Netflix
# JioHotstar
# JioHotstar
# Netflix
# Amazon Prime Video
# Netflix
# Crunchyroll
# Amazon Prime Video
# JioHotstar
# Crunchyroll
# JioHotstar
# Amazon Prime Video
# Netflix
# Crunchyroll
# Amazon Prime Video
# Amazon Prime Video
# Netflix
# Amazon Prime Video
# JioHotstar
# Apple TV Store
# Netflix
# Crunchyroll
# Netflix
# JioHotstar
# Amazon Prime Video
# MX Player
# JioHotstar
# JustWatch
# JioHotstar
# Netflix
# JustWatch
# Amazon Prime Video
# Amazon Prime Video
# Netflix
# JioHotstar
# Amazon Prime Video
# Netflix
# Amazon Prime Video
# Amazon Prime Video
# Netflix
# Crunchyroll
# Netflix
# Netflix
# Netflix
# Amazon Prime Video
# Crunchyroll
# Crunchyroll
# Crunchyroll
# JioHotstar

# %% [markdown]
# ## **Fetching Duration Details**

# %%
# Create an empty list to store the duration (runtime)
# of all TV shows
durations = []


for url in tv_show_urls:


    response = requests.get(
        url,
        headers=headers
    )


    soup = BeautifulSoup(
        response.text,
        "html.parser"
    )

    # Initialize the duration variable with NaN
    # This value will be used if no duration is found

    duration = np.nan

    # Find all <div> elements containing title details
    # such as JustWatch rank, IMDb score, and duration

    for item in soup.find_all(
        "div",
        class_="title-detail-hero-details__item"
    ):

        # Extract the text from the current detail item
        text = item.get_text(strip=True)

        # Check whether the text represents the TV show duration
        # Duration values usually contain "min"
        # Examples: "50min", "51min", "1h 6min"

        if "min" in text:

            # Store the extracted duration
            duration = text

            # Stop searching once the duration is found
            break

    # Add the extracted duration to the durations list
    durations.append(duration)

# Print the total number of duration entries extracted
print(len(durations))

# Print the duration of each TV show

for runtime in durations:
    print(runtime)
