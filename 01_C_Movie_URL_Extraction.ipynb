# %% [markdown]
# <a href="https://colab.research.google.com/github/ThirumalReddyPeddi/Numerical-Programming-in-Python---Web-Scraping.ipynb/blob/main/01_C_Movie_URL_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Fetching Movie URL's**

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.justwatch.com/in/movies?release_year_from=2000"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

# Create an empty list to store the movie URLs
movie_urls = []


# Find all anchor (<a>) tags that contain an href attribute
for a in soup.find_all("a", href=True):
   # Extract the href (link) from the current anchor tag
    href = a["href"]


    # Check whether the link corresponds to a movie page
    # Movie URLs on JustWatch contain '/movie/'
    if "/movie/" in href:

        # Convert the relative URL into a complete (absolute) URL
        full_url = "https://www.justwatch.com" + href

        # Add the full movie URL to the list
        movie_urls.append(full_url)

# Remove duplicate movie URLs by converting the list to a set and back to a list
movie_urls = list(set(movie_urls))

# Display the total number of unique movie URLs extracted
print(len(movie_urls))

# Create a final list containing all the extracted movie URLs
# (This step is optional since movie_urls already contains the required data)
final_url = [url for url in movie_urls]

# Print the list of all extracted movie URLs
print(final_url)
# Out:
# 105
# ['https://www.justwatch.com/in/movie/deadly-crush', 'https://www.justwatch.com/in/movie/365-days', 'https://www.justwatch.com/in/movie/dhurandhar-2025', 'https://www.justwatch.com/in/movie/balan-the-boy', 'https://www.justwatch.com/in/movie/mortal-kombat-2', 'https://www.justwatch.com/in/movie/the-gangster-the-cop-the-devil', 'https://www.justwatch.com/in/movie/two-autumns-in-paris', 'https://www.justwatch.com/in/movie/pabuya', 'https://www.justwatch.com/in/movie/bhooth-bangla', 'https://www.justwatch.com/in/movie/bugso', 'https://www.justwatch.com/in/movie/my-sole-desire', 'https://www.justwatch.com/in/movie/kd-the-devil', 'https://www.justwatch.com/in/movie/jumanji-3', 'https://www.justwatch.com/in/movie/your-fault-london', 'https://www.justwatch.com/in/movie/kartavya-2026', 'https://www.justwatch.com/in/movie/backrooms', 'https://www.justwatch.com/in/movie/sambhavam-adhyayam-onnu', 'https://www.justwatch.com/in/movie/ugly-story', 'https://www.justwatch.com/in/movie/skin-like-sun', 'https://www.justwatch.com/in/movie/peddi', 'https://www.justwatch.com/in/movie/my-body-is-not-obscene', 'https://www.justwatch.com/in/movie/nightmares-and-shadows', 'https://www.justwatch.com/in/movie/secrets-2022', 'https://www.justwatch.com/in/movie/project-hail-mary', 'https://www.justwatch.com/in/movie/all-eyes-off-me', 'https://www.justwatch.com/in/movie/dhurandhar-the-revenge', 'https://www.justwatch.com/in/movie/rendez-vous', 'https://www.justwatch.com/in